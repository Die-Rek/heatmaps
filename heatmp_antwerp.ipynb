# %%
# %%timeit

import cv2
from ultralytics import YOLO
import numpy as np

# provide points from image 1
pts_src = np.array([[792, 372], [226, 612], [1151, 539],  [679, 318],])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[150, 425],[146, 678],[270, 423], [69,425],])

# calculate matrix H
h1, status1 = cv2.findHomography(pts_src, pts_dst)


pts_src = np.array([[813, 353], [1142, 510], [401, 215],  [978, 182], [156, 231], [287, 164]])

pts_dst = np.array([[301, 685],[146, 678],[582, 687], [299,892], [805, 578], [800, 699]])

# calculate matrix H
h2, status1 = cv2.findHomography(pts_src, pts_dst)


# provide points from image 1
pts_src = np.array([[458, 457], [815, 209], [891, 569],  [347, 401],
                    #  [146, 135], [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[143, 727],[150, 425],[300, 700], [83,729],
                    #  [406, 747], [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h3, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[248, 223], [434, 209], [266, 467],  [923, 477], [535, 74], 
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[804, 576],[800, 700],[584, 699], [583,910], [1087, 970],
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h4, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1770, 172], [2265, 259], [1343, 1292],  [2044, 976], [535, 74], 
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[801, 579],[799, 686],[634, 482], [661,571], [1087, 970],
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h5, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[982, 766], [1272, 277], [1611, 765],  [1328, 200], [775, 481], [748, 244], [1497, 14],
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[1086, 698],[1414, 694],[1099, 817], [1529,699], [1257, 567], [1529, 415], [2193, 734],
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h8, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1621, 109], [1291, 1052], [600, 989],  [409, 698],
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[584, 685],[1102, 685],[1112, 800], [1040, 904],
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h9, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1801, 713], [1023, 873], [714, 1390],  [1302, 118], [2116, 251],  [386, 761],
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[1586, 809],[1529, 685],[1425, 695], [1966, 534], [1776, 860],  [1542, 430],
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h10, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[2348, 764], [1852, 996], [323, 40],  [1139, 24], [2202, 338],  
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[1584, 808],[1529, 685],[2049, 150], [1966, 534], [1776, 860], 
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h11, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1203, 531], [737, 405], [781, 219],  [568, 181], [443, 983],  [1409, 745],[2132, 1300]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[1257, 568],[1305, 686],[1235, 819], [1289, 900], [1418, 526], [1267, 504],[ 1270, 357]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h12, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1477, 627], [1113, 427], [2446, 1036],  [327, 1405], [1835, 873]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[1597, 255],[1627, 191],[1521, 416], [1436, 110], [1555, 304]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h13, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1454, 943], [1120, 251], [40, 545],  [990, 881], [754, 1263],[719, 557], [2462, 779]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[2046, 577],[2047, 148],[1603, 280], [1966, 535], [1913, 631], [1892, 378], [2321, 605]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h14, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[934, 1104], [2146, 504], [2356, 705],  [2063, 1341], [1614, 495],[772, 1280], [2241, 429], [2242, 1603], [700, 1900]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[2145, 744],[1553, 696],[1708, 511], [2081, 543], [1776, 853], [2191, 731], [1302, 694], [2090, 447], [2300, 617]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h16, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1034, 576], [714, 626], [821, 1262],  [1279, 1164], 
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[1900, 162],[1878, 107],[1758, 143], [1772, 201], 
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h17, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1473, 436], [1722, 448], [1350, 995],  [1734, 989], [1733,705]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[2771, 747],[2703, 760],[2697, 554], [2640, 584], [2662, 647]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h18, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[513, 1930], [218, 428], [2303, 465],  [2440, 960], 
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[2718, 214],[3364, 164],[2843, 678], [2688, 468], 
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h19, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1093, 1362], [721, 942], [1516, 1102],  [317, 1053], 
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[2692, 216],[2666, 144],[2718, 210], [2587, 141], 
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h20, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[1693, 492], [2196, 295], [867, 463],  [754, 291], [2094, 343], [316, 1411]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[3087, 340],[2690, 469],[3251, 414], [3260, 580], [2843, 407], [3347, 183]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h21, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[270, 1354], [1594, 419], [2297, 583],  [1737, 860], [1590,1592]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[3393, 758],[2956, 538],[3087, 350], [3268, 588], [3423, 630]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h22, status1 = cv2.findHomography(pts_src, pts_dst)

# provide points from image 1
pts_src = np.array([[619, 463], [416, 570], [948, 254],  [1372, 564], [265,1279]
                    # [1994, 539]
                    # [913, 806]
                    ])
# corresponding points from image 2 (i.e. (154, 174) matches (212, 80))
pts_dst = np.array([[3053, 520],[2958, 537],[3249, 428], [3094, 679], [2845,693]
                    #  [1918, 35]
                    # [27, 223]
                    ])

# calculate matrix H
h23, status1 = cv2.findHomography(pts_src, pts_dst)

def euclidian_distance(point, other):
     return np.linalg.norm(point-other)

model = YOLO("model_- 15 april 2024 18_14.pt") 
camera1 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch1_20240406140000_20240406150000.mp4")
camera2 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch2_20240406140000_20240406150000.mp4")
camera3 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch3_20240406140000_20240406150000.mp4")
camera4 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch4_20240406140000_20240406150000.mp4")
camera5 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch5_20240406140000_20240406150000.mp4")
camera8 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch8_20240406140000_20240406150000.mp4")
camera9 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch9_20240406140000_20240406150000.mp4")
camera10 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch10_20240406140000_20240406150000.mp4")
camera11 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch11_20240406140000_20240406150000.mp4")
camera12 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch12_20240406140000_20240406150000.mp4")
camera13 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch13_20240406140000_20240406150000.mp4")
camera14 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch14_20240406140000_20240406150000.mp4")
camera16 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch16_20240406140000_20240406150000.mp4")
camera17 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch17_20240406140000_20240406150000.mp4")
camera18 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch18_20240406140000_20240406150000.mp4")
camera19 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch19_20240406140000_20240406150000.mp4")
camera20 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch20_20240406140000_20240406150000.mp4")
camera21 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch21_20240406140000_20240406150000.mp4")
camera22 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch22_20240406140000_20240406150000.mp4")
camera23 = cv2.VideoCapture("D:/nike downloads/Antwerpen_06-04_1400-1500/Nike Antwerpen_ch23_20240406140000_20240406150000.mp4")

camera_list= [
    camera2,
    camera3,
    camera4,
    camera5,

    camera8,
    camera9,
    camera10,
    camera11,
    camera12,
    camera13,
    camera14,

    camera16,
    camera17,
    camera18,
    camera19,
    camera20,
    camera21,
    camera22,
    camera23,

]
img_counter = 0
count = 0
pointsOut = []
while True:
    ret1, frame1 = camera1.read()
    ret2, frame2 = camera2.read()
    ret3, frame3 = camera3.read()
    ret4, frame4 = camera4.read()
    ret5, frame5 = camera5.read()

    ret8, frame8 = camera8.read()
    ret9, frame9 = camera9.read()
    ret10, frame10 = camera10.read()
    ret11, frame11 = camera11.read()
    ret12, frame12 = camera12.read()
    ret13, frame13 = camera13.read()
    ret14, frame14 = camera14.read()

    ret16, frame16 = camera16.read()
    ret17, frame17 = camera17.read()
    ret18, frame18 = camera18.read()
    ret19, frame19 = camera19.read()
    ret20, frame20 = camera20.read()
    ret21, frame21 = camera21.read()
    ret22, frame22 = camera22.read()
    ret23, frame23 = camera23.read()


    ret_list =[
        ret1,
        ret2,
    ret3,
    ret4,
    ret5,

    ret8,
    ret9,
    ret10,
    ret11,
    ret12,
    ret13,
    ret14,

    ret16,
    ret17,
    ret18,
    ret19,
    ret20,
    ret21,
    ret22,
    ret23
    
    ]

    frame_list= [
        frame1,
                frame2,
    frame3,
    frame4,
    frame5,

    frame8,
    frame9,
    frame10,
    frame11,
    frame12,
    frame13,
    frame14,

    frame16,
    frame17,
    frame18,
    frame19,
    frame20,
    frame21,
    frame22,
    frame23
                    ]

    if not all(ret_list):
        print("failed to grab frame")
        break
    cv2.imshow("test", frame4)
    # cv2.imshow("test2", frame2)
    # cv2.imshow("test3", frame3)

    k = cv2.waitKey(1)
    if k%256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break
    else:
    
        for i, frame in enumerate(frame_list):
            # display(i)
            match i:
                case 0:
                    h= h1
                case 1:
                    h=h2
                case 2:
                    h=h3
                case 3:
                    h= h4
                case 4:
                    h=h5
                case 5:
                    h=h8
                case 6:
                    h= h9
                case 7:
                    h=h10
                case 8:
                    h=h11
                case 9:
                    h= h12
                case 10:
                    h=h13
                case 11:
                    h=h14
                case 12:
                    h= h16
                case 13:
                    h=h17
                case 14:
                    h=h18
                case 15:
                    h= h19
                case 16:
                    h=h20
                case 17:
                    h=h21
                case 18:
                    h=h22
                case 19:
                    h=h23
            img_path = "callibration_frames/Frame_{}_{}.jpg".format(img_counter, i)
            outs = model.predict(frame, verbose=False)
            boxes = outs[0].boxes
            allpoints=[]
            for j in range(len(boxes)):
                feet = [float(boxes[j].xyxy[0][2] - ((boxes[j].xyxy[0][2] - boxes[j].xyxy[0][0]) /2)), float(boxes[j].xyxy[0][3])]
                feet = [int(x) for x in feet]
                # display(feet)
                allpoints.append(feet)
                colored_frame = cv2.circle(frame, (feet[0], feet[1]), radius=1, color=(0,255,0), thickness=2)
                named_frame = cv2.putText(colored_frame, str(feet), (feet[0] + 10, feet[1]), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 1, cv2.LINE_AA)
            cv2.imwrite(img_path, frame)
            # cv2.imshow("valid", named_frame)
            # cv2.imwrite(img_path, named_frame)
            allpoints_np = np.array(allpoints, dtype='float32')
            allpoints_np = np.array([allpoints_np])
            if len(allpoints)>0:
                pointsOut_frame = cv2.perspectiveTransform(allpoints_np, h)
                for point in pointsOut_frame[0]:
                    if point[0] > 3000 or point[1] > 3000 or point[0] < 0 or point[1] < 0:
                        display((i, point))     
                    # display(point)
                    if len(pointsOut) == 0:
                        pointsOut.append(point)
                    distances = [euclidian_distance(p, point) for p in pointsOut]
                    if all([i> 10 for i in distances]):
                        pointsOut.append(point)
                    # display(distances)
        img_counter += 1
        count += 25
        for camera in camera_list:
            camera.set(cv2.CAP_PROP_POS_FRAMES, count)

camera1.release()
camera2.release()
camera3.release()
camera5.release()

camera4.release()


camera8.release()
camera9.release()
camera10.release()
camera11.release()
camera12.release()
camera13.release()
camera14.release()

camera16.release()
camera17.release()
camera18.release()
camera19.release()
camera20.release()
camera21.release()
camera22.release()
camera23.release()

# %%
pointsOut = [x for x in pointsOut if x[0] < 3800 and x[1] < 1100 and x[0] >0 and x[1] > 0]

# %%
x, y = zip(*pointsOut)
x, y

# %%
import matplotlib.pyplot as plt
plt.scatter(*zip(*pointsOut))
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.ndimage import gaussian_filter
img = plt.imread("D:/Bachelorproef/VSCodeFolder/groundplan/Nike antwerpen combined.png")

def myplot(x, y, s, bins=1000):
    heatmap, xedges, yedges = np.histogram2d(x, y, bins=bins)
    heatmap = gaussian_filter(heatmap, sigma=s)

    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    return heatmap.T, extent

def transparent_cmap(cmap, N=255):
    "Copy colormap and set alpha values"

    mycmap = cmap
    mycmap._init()
    mycmap._lut[:,-1] = np.linspace(0, 0.8, N+4)
    return mycmap

mycmap = transparent_cmap(plt.cm.plasma)

fig, ax = plt.subplots()
ax.imshow(img)
img, extent = myplot(x, y, 5)
# ax.plot(x, y, 'k.', markersize=5, color='red')
ax.imshow(img, extent=extent, origin='lower', cmap=mycmap)
ax.set_title("Smoothing with  $\sigma$ = %d" )

# %%
for i in range(0, 65, 5):
    img = plt.imread("D:/Bachelorproef/VSCodeFolder/groundplan/Nike antwerpen combined.png")
    fig, ax = plt.subplots()
    ax.imshow(img)
    img, extent = myplot(x, y, i)
    # ax.plot(x, y, 'k.', markersize=5, color='red')
    ax.imshow(img, extent=extent, origin='lower', cmap=mycmap)
    ax.set_title(f"Smoothing with  $\sigma$ = {i}" )
    fig.savefig(f"Heatmaps/heatmap_gradient{i}")
